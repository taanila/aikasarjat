# %% [markdown]
# # yfinance
#
# https://github.com/ranaroussi/yfinance
#
# yfinance-asennus Anaconda promptin kautta: **pip install yfinance --upgrade --no-cache-dir**

# %%
import pandas as pd

import yfinance as yf

# %%
stock = yf.Ticker('MSFT')

# %%
stock.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
df = stock.history(period = '3y')

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2019-02-20       0.46           0.0
# 2019-05-15       0.46           0.0
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
# 2020-02-19       0.51           0.0
# 2020-05-20       0.51           0.0
# 2020-08-19       0.51           0.0
# 2020-11-18       0.56           0.0
# 2021-02-17       0.56           0.0
# 2021-05-19       0.56           0.0
# 2021-08-18       0.56           0.0
# 2021-11-17       0.62           0.0

# %%
stock.dividends
# Out:
# Date
# 2019-02-20    0.46
# 2019-05-15    0.46
# 2019-08-14    0.46
# 2019-11-20    0.51
# 2020-02-19    0.51
# 2020-05-20    0.51
# 2020-08-19    0.51
# 2020-11-18    0.56
# 2021-02-17    0.56
# 2021-05-19    0.56
# 2021-08-18    0.56
# 2021-11-17    0.62
# Name: Dividends, dtype: float64

# %%
stock.splits
# Out:
# Series([], Name: Stock Splits, dtype: int64)

# %%
stock.financials
# Out:
#                                             2021-06-30      2020-06-30  \
# Research Development                     20716000000.0   19269000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        71102000000.0   53036000000.0
# Minority Interest                                 None            None
# Net Income                               61271000000.0   44281000000.0
# Selling General Administrative           25224000000.0   24523000000.0
# Gross Profit                            115856000000.0   96937000000.0
# Ebit                                     69916000000.0   53145000000.0
# Operating Income                         69916000000.0   53145000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2330000000.0   -2591000000.0
# Extraordinary Items                               None            None
# ...

# %%
stock.quarterly_financials
# Out:
#                                            2021-09-30     2021-06-30  \
# Research Development                     5599000000.0   5687000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       20524000000.0  19405000000.0
# Minority Interest                                None           None
# Net Income                              20505000000.0  16458000000.0
# Selling General Administrative           5834000000.0   7379000000.0
# Gross Profit                            31671000000.0  32161000000.0
# Ebit                                    20238000000.0  19095000000.0
# Operating Income                        20238000000.0  19095000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -535000000.0   -549000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
stock.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  71.87%       % of Shares Held by Institutions
# 2  71.92%        % of Float Held by Institutions
# 3    5375  Number of Institutions Holding Shares

# %%
stock.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  613781686    2021-09-29  0.0818
# 1                     Blackrock Inc.  507117032    2021-09-29  0.0675
# 2           State Street Corporation  294432926    2021-09-29  0.0392
# 3                           FMR, LLC  215731468    2021-09-29  0.0287
# 4      Price (T.Rowe) Associates Inc  197579453    2021-09-29  0.0263
# 5      Geode Capital Management, LLC  126079812    2021-09-29  0.0168
# 6            Capital World Investors  110359787    2021-09-29  0.0147
# 7  Capital Research Global Investors   94282634    2021-09-29  0.0126
# 8    Capital International Investors   91901445    2021-09-29  0.0122
# 9         Northern Trust Corporation   89592127    2021-09-29  0.0119
#
#           Value
# 0  173037332917
# 1  142966433661
# 2   83006530497
# 3   60819015458
# 4   55701599389
# 5   35544420599
# 6   31112631151
# 7   26580160177
# 8   25908855374
# 9   25257812443

# %%
stock.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  212378335    2021-09-29
# 1                            Vanguard 500 Index Fund  157812389    2021-09-29
# 2                             SPDR S&P 500 ETF Trust   79461013    2021-09-29
# 3                            Fidelity 500 Index Fund   71895960    2021-09-29
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   64566550    2021-09-29
# 5                         Vanguard Growth Index Fund   59312522    2021-09-29
# 6                           iShares Core S&P 500 ETF   58879615    2021-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   57658777    2021-09-29
# 8                         Growth Fund Of America Inc   54693909    2021-09-29
# 9         Vanguard Information Technology Index Fund   33363368    2021-08-30
#
#     % Out        Value
# 0  0.0283  59873700203
# 1  0.0210  44490468706
# 2  0.0106  22401648784
# ...

# %%
stock.balance_sheet
# Out:
#                                     2021-06-30    2020-06-30    2019-06-30  \
# Intangible Assets                 7.800000e+09  7.038000e+09  7.750000e+09
# Total Liab                        1.917910e+11  1.830070e+11  1.842260e+11
# Total Stockholder Equity          1.419880e+11  1.183040e+11  1.023300e+11
# Other Current Liab                5.261200e+10  4.600100e+10  4.586000e+10
# Total Assets                      3.337790e+11  3.013110e+11  2.865560e+11
# Common Stock                      8.311100e+10  8.055200e+10  7.852000e+10
# Other Current Assets              1.347100e+10  1.151700e+10  1.013300e+10
# Retained Earnings                 5.705500e+10  3.456600e+10  2.415000e+10
# Other Liab                        3.168100e+10  3.449200e+10  3.569900e+10
# Good Will                         4.971100e+10  4.335100e+10  4.202600e+10
# Treasury Stock                    1.822000e+09  3.186000e+09 -3.400000e+08
# ...

# %%
stock.quarterly_balance_sheet
# Out:
#                                     2021-09-30    2021-06-30    2021-03-31  \
# Intangible Assets                 7.794000e+09  7.800000e+09  8.127000e+09
# Total Liab                        1.834400e+11  1.917910e+11  1.743740e+11
# Total Stockholder Equity          1.519780e+11  1.419880e+11  1.345050e+11
# Other Current Liab                5.262200e+10  5.261200e+10  4.006900e+10
# Total Assets                      3.354180e+11  3.337790e+11  3.088790e+11
# Common Stock                      8.375100e+10  8.311100e+10  8.230800e+10
# Other Current Assets              1.298200e+10  1.347100e+10  1.203400e+10
# Retained Earnings                 6.694400e+10  5.705500e+10  5.073500e+10
# Other Liab                        3.015700e+10  3.168100e+10  3.160100e+10
# Good Will                         5.045500e+10  4.971100e+10  4.969800e+10
# Treasury Stock                    1.283000e+09  1.822000e+09  1.462000e+09
# ...

# %%
stock.cashflow
# Out:
#                                              2021-06-30    2020-06-30  \
# Investments                                2.876000e+09  6.980000e+09
# Change To Liabilities                      7.431000e+09  5.230000e+09
# Total Cashflows From Investing Activities -2.757700e+10 -1.222300e+10
# Net Borrowings                            -3.750000e+09 -5.518000e+09
# Total Cash From Financing Activities      -4.848600e+10 -4.603100e+10
# Change To Operating Activities             1.160000e+09 -6.730000e+08
# Issuance Of Stock                          1.693000e+09  1.343000e+09
# Net Income                                 6.127100e+10  4.428100e+10
# Change In Cash                             6.480000e+08  2.220000e+09
# Repurchase Of Stock                       -2.738500e+10 -2.296800e+10
# Effect Of Exchange Rate                   -2.900000e+07 -2.010000e+08
# Total Cash From Operating Activities       7.674000e+10  6.067500e+10
# ...

# %%
stock.quarterly_cashflow
# Out:
#                                              2021-09-30    2021-06-30  \
# Investments                                4.183000e+09 -4.334000e+09
# Change To Liabilities                     -3.356000e+09  1.301400e+10
# Total Cashflows From Investing Activities -3.250000e+09 -1.085300e+10
# Net Borrowings                            -4.826000e+09 -4.826000e+09
# Total Cash From Financing Activities      -1.627600e+10 -1.137100e+10
# Change To Operating Activities            -3.551000e+09  7.990000e+08
# Issuance Of Stock                          6.120000e+08  4.500000e+08
# Net Income                                 2.050500e+10  1.645800e+10
# Change In Cash                             4.941000e+09  5.220000e+08
# Repurchase Of Stock                       -7.684000e+09 -7.177000e+09
# Effect Of Exchange Rate                   -7.300000e+07  3.600000e+07
# Total Cash From Operating Activities       2.454000e+10  2.271000e+10
# ...

# %%
stock.earnings
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
stock.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 4Q2020   43076000000  15463000000
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000
# 3Q2021   45317000000  20505000000

# %%
stock.sustainability
# Out:
#                                      Value
# 2021-9
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           8.06
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                               99
# governanceScore                       4.73
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             13.26
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
stock.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2021-10-27 12:37:42   Credit Suisse     Outperform              main
# 2021-10-27 13:41:53        Barclays     Overweight              main
# 2021-10-27 13:56:33  Morgan Stanley     Overweight              main
# 2021-10-28 14:55:44       Citigroup            Buy              main
# 2021-11-02 09:45:19   Deutsche Bank            Buy              init
#
# [358 rows x 4 columns]

# %%
stock.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-01-24 10:59:00  2022-01-28 12:00:00
# Earnings Average                 2.31                 2.31
# Earnings Low                     2.27                 2.27
# Earnings High                    2.46                 2.46
# Revenue Average           50830400000          50830400000
# Revenue Low               50536700000          50536700000
# Revenue High              51555000000          51555000000

# %%
stock.isin
# Out:
# 'US5949181045'

# %%
stock.options
# Out:
# ('2021-12-10',
#  '2021-12-17',
#  '2021-12-23',
#  '2021-12-31',
#  '2022-01-07',
#  '2022-01-14',
#  '2022-01-21',
#  '2022-02-18',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-06-17',
#  '2022-07-15',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2024-01-19')

# %%
stock.news
# Out:
# [{'uuid': 'fb946b77-6906-3a7f-8ac6-b284e3dafb19',
#   'title': 'Dow Jones Futures Rally: Is Stock Market Correction Over? What To Do Now',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/fb946b77-6906-3a7f-8ac6-b284e3dafb19/dow-jones-futures-rally%3A-is.html',
#   'providerPublishTime': 1638848638,
#   'type': 'STORY'},
#  {'uuid': 'f17bf396-669d-357a-bf0c-17f5968afba2',
#   'title': "Microsoft and AWS 'make up about half of the overall cloud software market': Analyst",
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/microsoft-aws-half-overall-cloud-230821529.html',
#   'providerPublishTime': 1638832101,
#   'type': 'VIDEO'},
#  {'uuid': '66349bb6-ef0a-3fa5-a953-7ada10bf8718',
#   'title': "Tracking Microsoft's moves beyond software",
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/tracking-microsofts-moves-beyond-software-224236508.html',
# ...
